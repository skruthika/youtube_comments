# %%
import os
import json
from googleapiclient.discovery import build

# Set your API key (replace with your actual API key)
api_key = "AIzaSyBUO3Ng21xrXepEwabtdbb18-8A2Aj5_78"

# Initialize the YouTube Data API client
youtube = build("youtube", "v3", developerKey=api_key)

# Define the video ID you want to retrieve comments for
video_id = "FnaOb4wtJDk"

# Retrieve video details
video_response = youtube.videos().list(id=video_id, part="snippet,statistics").execute()
video_info = video_response["items"][0]

# Print video information
print("Video Title:", video_info["snippet"]["title"])
print("Views:", video_info["statistics"]["viewCount"])
print("Likes:", video_info["statistics"]["likeCount"])
if 'dislikeCount' in video_info["statistics"]:
    print("Dislikes:", video_info["statistics"]["dislikeCount"])
else:
    print("Dislikes: Not Available")

# Retrieve video comments
comments = []
next_page_token = None


while True:
    comment_response = youtube.commentThreads().list(
        part="snippet",
        videoId=video_id,
        textFormat="plainText",
        maxResults=100,  # Adjust as needed

        pageToken=next_page_token,
    ).execute()

    for comment in comment_response["items"]:
        text = comment["snippet"]["topLevelComment"]["snippet"]["textDisplay"]
        comments.append(text)

    next_page_token = comment_response.get("nextPageToken")

    if not next_page_token:
        break

# Print the first few comments
for i, comment in enumerate(comments[:5]):
    print(f"Comment {i+1}: {comment}")

# Save comments to a JSON file
with open("youtube_comments.json", "w", encoding="utf-8") as json_file:
    json.dump(comments, json_file, ensure_ascii=False, indent=4)
# Out:
# Video Title: Branding Ad - Dino
# Views: 4813328
# Likes: 857
# Dislikes: Not Available
# Comment 1: i love this ad
# Comment 2: اين فلسطين 🇵🇸
# Comment 3: its Jason Gray from studio c💖💖
# Comment 4: I am Indian
# Comment 5: useful tool thx

# %%
import os
import json
from googleapiclient.discovery import build

# Set your API key (replace with your actual API key)
api_key = "AIzaSyBUO3Ng21xrXepEwabtdbb18-8A2Aj5_78"

# Initialize the YouTube Data API client
youtube = build("youtube", "v3", developerKey=api_key)

# Define the video ID you want to retrieve comments for
video_id = "FnaOb4wtJDk"

# Retrieve video details
video_response = youtube.videos().list(id=video_id, part="snippet,statistics").execute()
video_info = video_response["items"][0]

# Print video information
print("Video Title:", video_info["snippet"]["title"])
print("Views:", video_info["statistics"]["viewCount"])
print("Likes:", video_info["statistics"]["likeCount"])
if 'dislikeCount' in video_info["statistics"]:
    print("Dislikes:", video_info["statistics"]["dislikeCount"])
else:
    print("Dislikes: Not Available")

# Retrieve video comments
comments = []
next_page_token = None

while True:
    comment_response = youtube.commentThreads().list(
        part="snippet",
        videoId=video_id,
        textFormat="plainText",
        maxResults=100,  # Adjust as needed
        pageToken=next_page_token,
    ).execute()

    for comment in comment_response["items"]:
        snippet = comment["snippet"]
        text = snippet["topLevelComment"]["snippet"]["textDisplay"]
        published_at = snippet["topLevelComment"]["snippet"]["publishedAt"]

        # Display the comment with its published time
        print(f"Published at {published_at}: {text}")

        comments.append((published_at, text))

    next_page_token = comment_response.get("nextPageToken")

    if not next_page_token:
        break

# Save comments to a JSON file
with open("youtube_comments.json", "w", encoding="utf-8") as json_file:
    json.dump(comments, json_file, ensure_ascii=False, indent=4)
# Out:
# Video Title: Branding Ad - Dino
# Views: 4813328
# Likes: 857
# Dislikes: Not Available
# Published at 2023-10-21T21:42:24Z: i love this ad
# Published at 2023-10-21T19:42:50Z: اين فلسطين 🇵🇸
# Published at 2023-10-20T20:42:24Z: its Jason Gray from studio c💖💖
# Published at 2023-10-20T13:39:25Z: I am Indian
# Published at 2023-10-20T01:46:47Z: useful tool thx
# Published at 2023-10-16T09:41:08Z: dino boy... nothing else, lol.
# Published at 2023-10-14T17:00:41Z: @ScientistFacts🎉
# Published at 2023-10-10T17:32:22Z: Also you have usu personal optimisation for your personal link selling & make money.  Like this idiotic post___
# Published at 2023-10-10T17:28:49Z: And basically, you are come here for your personal profit. Not social___thank you
# Published at 2023-10-10T15:55:47Z: Nice
# Published at 2023-10-08T21:26:10Z: I love this ad
# Published at 2023-10-06T20:59:28Z: BEST AD HHHHHHHHHHHHH
# Published at 2023-10-06T18:10:19Z: incredible ad!
# ...

# %%
import os
from googleapiclient.discovery import build
from datetime import datetime

# Set your API key (replace with your actual API key)
api_key = "AIzaSyBUO3Ng21xrXepEwabtdbb18-8A2Aj5_78"

# Initialize the YouTube Data API client
youtube = build("youtube", "v3", developerKey=api_key)

# Define the video ID you want to retrieve comments for
video_id = "FnaOb4wtJDk"

start_date = "2023-05-01T00:00:00Z"  # Replace with your desired start date
end_date = "2023-10-31T23:59:59Z"  # Replace with your desired end date

start_datetime = datetime.strptime(start_date, "%Y-%m-%dT%H:%M:%SZ")
end_datetime = datetime.strptime(end_date, "%Y-%m-%dT%H:%M:%SZ")


# Retrieve video details
video_response = youtube.videos().list(id=video_id, part="snippet,statistics").execute()
video_info = video_response["items"][0]

# Print video information
print("Video Title:", video_info["snippet"]["title"])
print("Views:", video_info["statistics"]["viewCount"])
print("Likes:", video_info["statistics"]["likeCount"])
if 'dislikeCount' in video_info["statistics"]:
    print("Dislikes:", video_info["statistics"]["dislikeCount"])
else:
    print("Dislikes: Not Available")

# Retrieve video comments within the specified duration
comments = []
next_page_token = None

while True:
    comment_response = youtube.commentThreads().list(
        part="snippet",
        videoId=video_id,
        textFormat="plainText",
        maxResults=100,  # Adjust as needed
        pageToken=next_page_token,
    ).execute()

    for comment in comment_response["items"]:
        snippet = comment["snippet"]
        text = snippet["topLevelComment"]["snippet"]["textDisplay"]
        published_at =datetime.strptime(snippet["topLevelComment"]["snippet"]["publishedAt"],"%Y-%m-%dT%H:%M:%SZ")
        print(published_at)

        if start_datetime <= published_at <= end_datetime:
            # Display the comment with its published time
            print(f"Published at {published_at}: {text}")

            comments.append((published_at, text))

    next_page_token = comment_response.get("nextPageToken")

    if not next_page_token:
        break
# Out:
# Video Title: Branding Ad - Dino
# Views: 4813371
# Likes: 857
# Dislikes: Not Available
# 2023-10-21 21:42:24
# Published at 2023-10-21 21:42:24: i love this ad
# 2023-10-21 19:42:50
# Published at 2023-10-21 19:42:50: اين فلسطين 🇵🇸
# 2023-10-20 20:42:24
# Published at 2023-10-20 20:42:24: its Jason Gray from studio c💖💖
# 2023-10-20 13:39:25
# Published at 2023-10-20 13:39:25: I am Indian
# 2023-10-20 01:46:47
# Published at 2023-10-20 01:46:47: useful tool thx
# 2023-10-16 09:41:08
# Published at 2023-10-16 09:41:08: dino boy... nothing else, lol.
# 2023-10-14 17:00:41
# Published at 2023-10-14 17:00:41: @ScientistFacts🎉
# 2023-10-10 17:32:22
# Published at 2023-10-10 17:32:22: Also you have usu personal optimisation for your personal link selling & make money.  Like this idiotic post___
# 2023-10-10 17:28:49
# Published at 2023-10-10 17:28:49: And basically, you are come here for your personal profit. Not social___thank you
# 2023-10-10 15:55:47
# ...

# %%
import os
import csv
from googleapiclient.discovery import build
from datetime import datetime

# Set your API key (replace with your actual API key)
api_key = "AIzaSyBUO3Ng21xrXepEwabtdbb18-8A2Aj5_78"

# Initialize the YouTube Data API client
youtube = build("youtube", "v3", developerKey=api_key)

# Define the video ID you want to retrieve comments for
video_id = "FnaOb4wtJDk"

start_date = "2023-05-01T00:00:00Z"  # Replace with your desired start date
end_date = "2023-10-31T23:59:59Z"  # Replace with your desired end date

start_datetime = datetime.strptime(start_date, "%Y-%m-%dT%H:%M:%SZ")
end_datetime = datetime.strptime(end_date, "%Y-%m-%dT%H:%M:%SZ")

# Retrieve video details
video_response = youtube.videos().list(id=video_id, part="snippet,statistics").execute()
video_info = video_response["items"][0]

# Print video information
print("Video Title:", video_info["snippet"]["title"])
print("Views:", video_info["statistics"]["viewCount"])
print("Likes:", video_info["statistics"]["likeCount"])
if 'dislikeCount' in video_info["statistics"]:
    print("Dislikes:", video_info["statistics"]["dislikeCount"])
else:
    print("Dislikes: Not Available")

# Retrieve video comments within the specified duration
comments = []
next_page_token = None

while True:
    comment_response = youtube.commentThreads().list(
        part="snippet",
        videoId=video_id,
        textFormat="plainText",
        maxResults=100,  # Adjust as needed
        pageToken=next_page_token,
    ).execute()

    for comment in comment_response["items"]:
        snippet = comment["snippet"]
        text = snippet["topLevelComment"]["snippet"]["textDisplay"]
        published_at = datetime.strptime(snippet["topLevelComment"]["snippet"]["publishedAt"], "%Y-%m-%dT%H:%M:%SZ")

        if start_datetime <= published_at <= end_datetime:
            comments.append((published_at, text))

    next_page_token = comment_response.get("nextPageToken")

    if not next_page_token:
        break

# Save comments as a CSV file
csv_filename = "youtube_comments.csv"

with open(csv_filename, "w", newline="", encoding="utf-8") as csv_file:
    csv_writer = csv.writer(csv_file)
    csv_writer.writerow(["Published At", "Comment"])

    for comment in comments:
        csv_writer.writerow([comment[0], comment[1]])

print(f"Comments have been saved to {csv_filename}")
# Out:
# Video Title: Branding Ad - Dino
# Views: 4813371
# Likes: 857
# Dislikes: Not Available
# Comments have been saved to youtube_comments.csv

# %%
import pandas as pd
import numpy as np
df=pd.read_csv("/content/youtube_comments.csv")
df
# Out:
#            Published At                                            Comment
# 0   2023-10-21 21:42:24                                     i love this ad
# 1   2023-10-21 19:42:50                                      اين فلسطين 🇵🇸
# 2   2023-10-20 20:42:24                     its Jason Gray from studio c💖💖
# 3   2023-10-20 13:39:25                                        I am Indian
# 4   2023-10-20 01:46:47                                    useful tool thx
# 5   2023-10-16 09:41:08                     dino boy... nothing else, lol.
# 6   2023-10-14 17:00:41                                   @ScientistFacts🎉
# 7   2023-10-10 17:32:22  Also you have usu personal optimisation for yo...
# 8   2023-10-10 17:28:49  And basically, you are come here for your pers...
# 9   2023-10-10 15:55:47                                               Nice
# 10  2023-10-08 21:26:10                                     I love this ad
# ...

# %%
df.shape
# Out:
# (41, 2)

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Embedding, LSTM, Dense, Bidirectional, Flatten
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
data = pd.read_csv('/content/youtube_comments.csv')

# %%
import re

# Function to clean and preprocess text
def clean_text(text):
    # Convert text to lowercase
    text = text.lower()

    # Remove emojis
    text = re.sub(r'\\x[a-f0-9]{2}', '', text)

    # Remove punctuation and special characters
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)

    return text

data['Cleaned_Comment'] = data['Comment'].apply(clean_text)

# %%
data.head()
# Out:
#           Published At                         Comment  \
# 0  2023-10-21 21:42:24                  i love this ad
# 1  2023-10-21 19:42:50                   اين فلسطين 🇵🇸
# 2  2023-10-20 20:42:24  its Jason Gray from studio c💖💖
# 3  2023-10-20 13:39:25                     I am Indian
# 4  2023-10-20 01:46:47                 useful tool thx
#
#                 Cleaned_Comment
# 0                i love this ad
# 1
# 2  its jason gray from studio c
# 3                   i am indian
# 4               useful tool thx

# %%
# Define a binary target variable (1 for good comments, 0 for bad comments)
data['rating'] = data['Comment'].apply(lambda x: 1 if 'nice' in x or 'love' in x or 'best' in x else 0)

# %%
data.head()
# Out:
#           Published At                         Comment  \
# 0  2023-10-21 21:42:24                  i love this ad
# 1  2023-10-21 19:42:50                   اين فلسطين 🇵🇸
# 2  2023-10-20 20:42:24  its Jason Gray from studio c💖💖
# 3  2023-10-20 13:39:25                     I am Indian
# 4  2023-10-20 01:46:47                 useful tool thx
#
#                 Cleaned_Comment  rating
# 0                i love this ad       1
# 1                                     0
# 2  its jason gray from studio c       0
# 3                   i am indian       0
# 4               useful tool thx       0

# %%
count_good_ratings = data['rating'].value_counts()[1]
print(f"Number of rows with a rating equal to 1: {count_good_ratings}")
# Out:
# Number of rows with a rating equal to 1: 9

# %%
good_comments = data[data['rating'] == 1]
good_comments_df = pd.DataFrame(good_comments)
good_comments_df
# Out:
#            Published At                                            Comment  \
# 0   2023-10-21 21:42:24                                     i love this ad
# 10  2023-10-08 21:26:10                                     I love this ad
# 15  2023-09-28 03:31:38               This is the best ad I've ever seen 😂
# 22  2023-09-04 07:27:51  this ad hits different, thanks u dino man, we ...
# 30  2023-07-29 22:34:01                                The only ad i loved
# 35  2023-06-12 13:58:34                                          love this
# 36  2023-06-12 13:55:52                                          love this
# 37  2023-06-12 13:49:24                                          love this
# 39  2023-05-16 01:59:57                      so nice thanks for this video
#
#                                       Cleaned_Comment  rating
# 0                                      i love this ad       1
# 10                                     i love this ad       1
# ...

# %%
good_comments_df.shape
# Out:
# (9, 4)

# %%
data.head()
# Out:
#           Published At                         Comment  \
# 0  2023-10-21 21:42:24                  i love this ad
# 1  2023-10-21 19:42:50                   اين فلسطين 🇵🇸
# 2  2023-10-20 20:42:24  its Jason Gray from studio c💖💖
# 3  2023-10-20 13:39:25                     I am Indian
# 4  2023-10-20 01:46:47                 useful tool thx
#
#                 Cleaned_Comment  rating
# 0                i love this ad       1
# 1                                     0
# 2  its jason gray from studio c       0
# 3                   i am indian       0
# 4               useful tool thx       0

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense
from sklearn.model_selection import train_test_split

X=data.iloc[:,2]

# Split the data
X_train, X_test, y_train, y_test = train_test_split(X, data['rating'], test_size=0.2, random_state=42)

# Tokenization and Padding
max_sequence_length = 100  # Adjust as needed
tokenizer = Tokenizer(num_words=5000)  # Adjust vocabulary size
tokenizer.fit_on_texts(X_train)
X_train = tokenizer.texts_to_sequences(X_train)
X_test = tokenizer.texts_to_sequences(X_test)
X_train = pad_sequences(X_train, maxlen=max_sequence_length)
X_test = pad_sequences(X_test, maxlen=max_sequence_length)

# Build a Text Classification Model
model = Sequential()
model.add(Embedding(input_dim=5000, output_dim=64, input_length=max_sequence_length))
model.add(LSTM(64))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model.fit(X_train, y_train, epochs=5, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/5
# 1/1 [==============================] - 4s 4s/step - loss: 0.6930 - accuracy: 0.4375 - val_loss: 0.6748 - val_accuracy: 0.8889
# Epoch 2/5
# 1/1 [==============================] - 0s 159ms/step - loss: 0.6812 - accuracy: 0.7500 - val_loss: 0.6581 - val_accuracy: 0.8889
# Epoch 3/5
# 1/1 [==============================] - 0s 161ms/step - loss: 0.6699 - accuracy: 0.7500 - val_loss: 0.6412 - val_accuracy: 0.8889
# Epoch 4/5
# 1/1 [==============================] - 0s 191ms/step - loss: 0.6586 - accuracy: 0.7500 - val_loss: 0.6234 - val_accuracy: 0.8889
# Epoch 5/5
# 1/1 [==============================] - 0s 143ms/step - loss: 0.6467 - accuracy: 0.7500 - val_loss: 0.6038 - val_accuracy: 0.8889

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# Predict the labels for the test set
y_pred = (model.predict(X_test) > 0.5).astype(int)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')

# Generate a confusion matrix
confusion = confusion_matrix(y_test, y_pred)
print('Confusion Matrix:')
print(confusion)
# Out:
# 1/1 [==============================] - 0s 111ms/step
# Accuracy: 0.8888888888888888
# Confusion Matrix:
# [[8 0]
#  [1 0]]

# %%
# New comment
new_comment = "good vedio!"

# Preprocess the new comment
cleaned_new_comment = clean_text(new_comment)  # Assuming you have the 'clean_text' function

# Tokenize and pad the new comment
new_comment_sequence = tokenizer.texts_to_sequences([cleaned_new_comment])
new_comment_padded = pad_sequences(new_comment_sequence, maxlen=max_sequence_length)

# Predict whether the new comment is "good" or "bad"
prediction = (model.predict(new_comment_padded) > 0.5).astype(int)
print(prediction)
if prediction[0] == 1:
    print("The new comment is classified as 'good.'")
else:
    print("The new comment is classified as 'bad.'")
# Out:
# 1/1 [==============================] - 0s 30ms/step
# [[0]]
# The new comment is classified as 'bad.'

# %%
model.save("streamlit.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
from flask import Flask, request, jsonify
import tensorflow as tf
import numpy as np

app = Flask(__name__)

# Load the saved model
model = tf.keras.models.load_model("/content/streamlit.h5")

@app.route("/predict", methods=["POST"])
def predict():
    data = request.get_json()
    new_comment = data["comment"]
    # Preprocess the new comment
    cleaned_new_comment = clean_text(new_comment)  # Assuming you have the 'clean_text' function

    # Tokenize and pad the new comment
    new_comment_sequence = tokenizer.texts_to_sequences([cleaned_new_comment])
    new_comment_padded = pad_sequences(new_comment_sequence, maxlen=max_sequence_length)
    prediction = (model.predict(new_comment_padded) > 0.5).astype(int)

    return jsonify({"prediction": int(prediction[0])})

if __name__ == "__main__":
    app.run()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit
